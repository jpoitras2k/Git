# %% [markdown]
# KNN Classification using Python and Scikit-learn
# In the following section, you will see how to write a python code to use the Scikit-learn implementation of the KNN classification algorithm.
# In this section, you do not need your computer; you will just read and follow the example, unless you want to run codes step-by-step.
# Step 1
# Using Pandas, you should read the data first in the CSV format into a Pandas Data Frame.

# %%
import pandas as pd 
df = pd.read_csv("data.csv")

# %% [markdown]
# Step 2
# Normalize your data using Scikit-Learn's standard scaler.

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X = scaler.fit_transform(df)

# %% [markdown]
# Step 3
# Divide your data into train and test sets.

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y,
test_size=0.33, random_state=0)

# %% [markdown]
# Step 4
# Use the Scikit-learn implementation of the classifier.

# %%
from sklearn.neighbors import KNeighborsClassifier 
# Choose value of K 
K = 3
model = KNeighborsClassifier(n_neighbors=K)
model.fit(X_train, y_train)

# %% [markdown]
# Step 5
# Use the instance of KNeighborsClassifier() you created to predict your data.

# %%
y_pred = model.predict(X_test)

# %% [markdown]
# Step 6
# Get the accuracy_score value after fitting.
# Note:
# The function KNeighborsClassifier().score returns the accuracy_score of the prediction.

# %%
y_score= model.score(X_test)
