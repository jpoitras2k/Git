# %% [markdown]
# Classifying Iris using Random Forest
# Description
# To complete this mission, perform the following task I the provided editor:
#
# Step 1
#
# Let's try classifying the Iris dataset using Random Forests!
#
# To complete this mission, your code should perform the following tasks:
#
# 1.    Train a RandomForestClassifier model using X_train and y_train with the following parameters:
#
# random_state=0 (for consistent output)
# Information Gain criterion
# 50 estimators
# 2.    Score your model using X_test and y_test.
#
# Using the test dataset, your code should return the score of the model.
