# %% [markdown]
# Logistic Regression in Python
# In this section, you will learn how to write python code; to use the Scikit-learn implementation of the logistic regression algorithm.
# In this section, you do not need your computer; you will just read and follow the example, unless you want to run codes step-by-step.
# Step 1
# Using pandas, you should read the data first in the CSV format into a Pandas Dataframe.

# %%
import pandas as pd 
import sklearn
df = pd.read_csv("data.csv")
df.dtypes
df_y= df['diagnosis']
df_new = df.drop(columns=['diagnosis'], axis=True)
print(df_new.dtypes)
print(df_y)

for i =
# Out:
# id                           int64
# radius_mean                float64
# texture_mean               float64
# perimeter_mean             float64
# area_mean                  float64
# smoothness_mean            float64
# compactness_mean           float64
# concavity_mean             float64
# concave points_mean        float64
# symmetry_mean              float64
# fractal_dimension_mean     float64
# radius_se                  float64
# texture_se                 float64
# perimeter_se               float64
# area_se                    float64
# smoothness_se              float64
# compactness_se             float64
# concavity_se               float64
# concave points_se          float64
# symmetry_se                float64
# fractal_dimension_se       float64
# radius_worst               float64
# texture_worst              float64
# perimeter_worst            float64
# area_worst                 float64
# smoothness_worst           float64
# compactness_worst          float64
# ...

# %% [markdown]
# Step 2
# Normalize your data using Scikit-Learn's standard scaler.

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X = scaler.fit_transform(df)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_6424\3608812212.py in ?()
#       1 from sklearn.preprocessing import StandardScaler
#       2 scaler = StandardScaler()
# ----> 3 X = scaler.fit_transform(df)
#
# c:\Users\12505\Downloads\AI Bootcamp\Git\.venv\Lib\site-packages\sklearn\utils\_set_output.py in ?(self, X, *args, **kwargs)
#     314     @wraps(f)
#     315     def wrapped(self, X, *args, **kwargs):
# --> 316         data_to_wrap = f(self, X, *args, **kwargs)
#     317         if isinstance(data_to_wrap, tuple):
#     318             # only wrap the first output for cross decomposition
#     319             return_tuple = (
#
# c:\Users\12505\Downloads\AI Bootcamp\Git\.venv\Lib\site-packages\sklearn\base.py in ?(self, X, y, **fit_params)
#     890                 )
#     891
#     892         if y is None:
# ...

# %% [markdown]
# Step 3
# Divide your data into train and test sets.

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y,
 test_size=0.33, random_state=0)

# %% [markdown]
# Step 4
# Use the Scikit-learn implementation of Logistic regression.
# Arguments to sklearn.linear_model.LogisticRegression:
# Solver: algorithm to use in the optimization problem. In this example and the editors, you will use LBFGS which is used for multi-class problems.
# Ovr: binary classification algorithm used for binary classes.
# LBFGS: multi-class output.
# multi_class: is an argument that utilizes the algorithm for multiclass output or binary outputs. You will simply choose the value to be 'auto,' which automatically uses a multi-class algorithm in case of multiple output classes and a binary algorithm in case of binary problems.

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression(solver = 'lbfgs', multi_class = 'auto')
model.fit(X_train, y_train)

# %% [markdown]
# Step 5
# Use the instance of LogisticRegression() you created to predict your data.

# %%
y_pred = model.predict(X_test)

# %% [markdown]
# Step 6
# Get the accuracy value after fitting.
# Note:
# The function LogisticRegression().score returns the accuracy of the prediction.

# %%
score = model.score(X_test,y_test)
print(score)
