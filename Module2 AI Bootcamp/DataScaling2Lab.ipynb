# %% [markdown]
# Instructions
#
# To complete this mission, perform the following tasks in the editor provided :
#
# You will now retry scaling the Iris dataset!
#
# Your code should perform the following tasks to complete this mission in the editor provided:
#
# Load the Iris dataset from scikit-learn as a data vector X and a label vector y.
# Scale the first two columns of the data vector X with a standard scaler (normalize them).
# Your code should return the scaled data vector scaled_columns (a 2D array with only the 2 scaled columns).
#
# SELF-CHECK: notice the result of calling mean(axis=0) and var(axis=0) (or var(axis=0)) for scaled_columns!
#
# Revisit the Iris dataset, here.

# %%
# Write your code here. Do not change any other parts of the code
from sklearn.datasets import load_iris
X, y = load_iris(return_X_y=True)
import numpy as np

from sklearn.preprocessing import StandardScaler  
scaler = StandardScaler()
X_to_scale = X[:, :2]  # Scaling only the first two columns
scaler = StandardScaler()
scaled_columns = scaler.fit_transform(X_to_scale)

#Leave this part as is, part of the Lab.
print(np.mean(scaled_columns))    
#return scaled_columns
# Out:
# -1.6460906711775654e-15
