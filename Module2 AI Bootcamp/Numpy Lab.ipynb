# %%
import pandas as pd

employees = pd.DataFrame({
    'name': ['Ali', 'Sara', 'John', 'Maya', 'Omar'],
    'department': ['HR', 'IT', 'IT', 'Finance', 'Finance'],
    'salary': [5000, 7000, 6500, 8000, 7200],
    'years_experience': [2, 5, 4, 7, 6]
})

#find all the employees that earn more than 7k
high_salaries = employees.loc[:, 'salary'] >7000  # Creates a Boolean List 
high_salaries = employees[ high_salaries]  # Chooses True Values as data
#print(high_salaries)

high_salaries_2 = employees.loc[employees['salary'] >7000, :]   #Filtering is done by row, on column 'salary'
#print (high_salaries_2)


#find the largest mean for each department.
largest_mean = employees.groupby('department')['salary'].mean()


#find department with highest individual salary
dept_highest_salary = department_max_salary.idxmax()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 24
#      20 largest_mean = employees.groupby('department')['salary'].mean()
#      23 #find department with highest individual salary
# ---> 24 dept_highest_salary = department_max_salary.idxmax()
#
# NameError: name 'department_max_salary' is not defined
