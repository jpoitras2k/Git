# %% [markdown]
# This sample code aims at finding best KNN Model based on best n_neighbors.

# %%
import numpy as np
from sklearn.neighbors import KNeighborsClassifier
neighbors = [2,3,5,7,9]
train_accuracy = np.empty((0, len(neighbors)))
test_accuracy = np.empty((0,len(neighbors)))
  
# Loop over K values
for i, k in enumerate(neighbors):
    knn = KNeighborsClassifier(n_neighbors=k)
    knn.fit(X_train, y_train)
      
    # Compute training and test data accuracy
    train_accuracy[i] = knn.score(X_train, y_train)
    test_accuracy[i] = knn.score(X_test, y_test)

# Get Best test Accuracy from List 
# Use the corresponding n_neighbors
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 10
#       8 for i, k in enumerate(neighbors):
#       9     knn = KNeighborsClassifier(n_neighbors=k)
# ---> 10     knn.fit(X_train, y_train)
#      12     # Compute training and test data accuracy
#      13     train_accuracy[i] = knn.score(X_train, y_train)
#
# NameError: name 'X_train' is not defined
