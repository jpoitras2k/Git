# %% [markdown]
# Mission instructions:
#
# The Cereals dataset has a plethora of categorical attributes, you will now use it for practicing!
#
# To complete this mission, perform the following task in the editor provided:
#
# Replace the (“C”,”H”) values in the “type” attribute with (“Cold”,”Hot” ) respectively.
#
# Hint: Create a new function that has a dictionary whose indices are the original values of “Type” attribute and its values are the new values. Then, pass this function as an argument to “Apply” function as described in the lesson.

# %%
import pandas as pd
dataset = pd.read_csv('cereal.csv')
# Step1: Replace the (“C”,”H”) values in the “type” attribute with (“Cold”,”Hot” ) respectively. 
dataset["type"] = dataset["type"].replace({"C": "Cold", "H": "Hot"})

print("dataset type:", dataset["type"])
#return dataset
# Out:
# dataset type: 0     Cold
# 1     Cold
# 2     Cold
# 3     Cold
# 4     Cold
#       ...
# 72    Cold
# 73    Cold
# 74    Cold
# 75    Cold
# 76    Cold
# Name: type, Length: 77, dtype: object
