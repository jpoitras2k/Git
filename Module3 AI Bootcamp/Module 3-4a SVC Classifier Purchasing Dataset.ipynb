# %% [markdown]
# # <center> Using a Support Vector Classifier (SVC) <br> to Train a Classification Model <br> on the Purchasing Dataset</center>
# <center> by: Nicole Woodland, P. Eng. for RoboGarden Inc. </center>
#
# ---
#
# Support Vector Classifiers are a method under the umbrella of Support Vector Machines (SVM's) available in the ScikitLearn Library. They aim to transform data into a higher dimensional space, using a kernal, to allow identification of new patterns that seperate the data and can be used to identify the labels for the predictions.
#
# In SVC's the parameters adjust to match the chosen Kernel.
#
# <br> Available Kernels:
# - linear
# - poly
# - rbf (default)
# - sigmoid
# - precomputed
#
# Required Parameters for Chosen Kernel:
# <br>**All**:
# - **C:** float, default=1.0 The Regularization parameter. The strength of the regularization is inversely proportional to C. Must be positive. It basically controls the balance between maximizing the margin and minimizing classification error.
# - **tol:** float, default=1e-3  Tolerance for stopping criterion. A measure of how stable is good enough.
# - **max_iter:** int, default=-1 Hard limit on iterations within solver, or -1 for no limit.
#
# Linear:
# - none
#
# Poly:
# - **degree:** The degree of the polynomial kernel function. Must be non-negative.
# - **gamma:** the Kernel coefficient. Choose one of:
# - 'scale' (default) is passed then it uses 1 / (n_features * X.var()) or
# - 'auto' = 1 / n_features or float,
# - 'float' = must be non-negative
#
#
# rbf (default):
# - **gamma:** the Kernel coefficient. Choose one of:
# - 'scale' (default) is passed then it uses 1 / (n_features * X.var()) or
# - 'auto' = 1 / n_features or float,
# - 'float' = must be non-negative

# %% [markdown]
# ## Read data from csv file and perform preprocessing

# %%
import pandas as pd
df = pd.read_csv("Social_Network_Ads.csv")

pd.set_option("display.max_columns", None)
pd.set_option("display.max_rows", 10)

# %%
# Create X and y data
x_columns = 2
X = df.iloc[:, 0:x_columns].values
y = df.iloc[:, x_columns].values

# %%
df
# Out:
#      Age  EstimatedSalary  Purchased
# 0     19            19000          0
# 1     35            20000          0
# 2     26            43000          0
# 3     27            57000          0
# 4     19            76000          0
# ..   ...              ...        ...
# 395   46            41000          1
# 396   51            23000          1
# 397   50            20000          1
# 398   36            33000          0
# 399   49            36000          1
#
# [400 rows x 3 columns]

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X = scaler.fit_transform(X)

# %% [markdown]
# ## Create training and testing sets

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, 
                                                    test_size=0.25, 
                                                    random_state=1)

# %% [markdown]
# ## Support Vector Machines (SVM) Classifier

# %%
# Access the module in sklearn to do the SVM analysis (must be capitalized, it's a class)
from sklearn.svm import SVC

# %%
# Create an instance of 'svm_model' with the RBF Kernel
svm_model = SVC(max_iter = 1000,
               kernel = "rbf",
               C = 1.0,
               gamma = 'scale'
               ) # max_iter is not required, but can prevent crashing when models don't converge as the default is unlimited iterations

# %%
# Training and fitting the model now
svm_model.fit(X_train, y_train)
# Out:
# SVC(max_iter=1000)

# %%
# Check the model score!
svm_model.score(X_test,y_test)
# Out:
# 0.88

# %%
# Guess what, time to do the predictions!
from sklearn.metrics import classification_report, confusion_matrix
predictions = svm_model.predict(X_test)

print(confusion_matrix(y_test,predictions))
print(classification_report(y_test,predictions))
# Out:
# [[49  9]
#  [ 3 39]]
#               precision    recall  f1-score   support
#
#            0       0.94      0.84      0.89        58
#            1       0.81      0.93      0.87        42
#
#     accuracy                           0.88       100
#    macro avg       0.88      0.89      0.88       100
# weighted avg       0.89      0.88      0.88       100

# %%
# Linear Model
svm_model = SVC(max_iter = 1000,
               kernel = "linear",
               C= 1.0,
               )

svm_model.fit(X_train, y_train)
svm_model.score(X_test,y_test)
# Out:
# 0.82

# %% [markdown]
# ### Optimize a SVC Model using GridSearch

# %%
param_grid = {'C': [0.1, 1, 10, 100, 1000],
              'gamma': [1, 0.1, 0.01, 0.001, 0.0001],
              'kernel': ['rbf',]}

# %%
# We need to import GridSearchCV from model_selection. ** Must be capitalized in GridSearchCV! **
from sklearn.model_selection import GridSearchCV

# %%
# refit = True by default, this re-trains the best model and saves it in 'grid' for further use. 
grid = GridSearchCV(SVC(max_iter = 1000000000), param_grid, verbose=3, refit = True) 

#grid is an instance of the gridsearch.

# %%
# Run a model and save the results for each combination of variables in the grid
grid.fit(X_train,y_train)
# Out:
# Fitting 5 folds for each of 25 candidates, totalling 125 fits
# [CV 1/5] END ........C=0.1, gamma=1, kernel=rbf;, score=0.833 total time=   0.0s
# [CV 2/5] END ........C=0.1, gamma=1, kernel=rbf;, score=0.917 total time=   0.0s
# [CV 3/5] END ........C=0.1, gamma=1, kernel=rbf;, score=0.900 total time=   0.0s
# [CV 4/5] END ........C=0.1, gamma=1, kernel=rbf;, score=0.967 total time=   0.0s
# [CV 5/5] END ........C=0.1, gamma=1, kernel=rbf;, score=0.900 total time=   0.0s
# [CV 1/5] END ......C=0.1, gamma=0.1, kernel=rbf;, score=0.800 total time=   0.0s
# [CV 2/5] END ......C=0.1, gamma=0.1, kernel=rbf;, score=0.867 total time=   0.0s
# [CV 3/5] END ......C=0.1, gamma=0.1, kernel=rbf;, score=0.783 total time=   0.0s
# [CV 4/5] END ......C=0.1, gamma=0.1, kernel=rbf;, score=0.883 total time=   0.0s
# [CV 5/5] END ......C=0.1, gamma=0.1, kernel=rbf;, score=0.867 total time=   0.0s
# [CV 1/5] END .....C=0.1, gamma=0.01, kernel=rbf;, score=0.667 total time=   0.0s
# [CV 2/5] END .....C=0.1, gamma=0.01, kernel=rbf;, score=0.667 total time=   0.0s
# [CV 3/5] END .....C=0.1, gamma=0.01, kernel=rbf;, score=0.667 total time=   0.0s
# [CV 4/5] END .....C=0.1, gamma=0.01, kernel=rbf;, score=0.667 total time=   0.0s
# [CV 5/5] END .....C=0.1, gamma=0.01, kernel=rbf;, score=0.650 total time=   0.0s
# [CV 1/5] END ....C=0.1, gamma=0.001, kernel=rbf;, score=0.667 total time=   0.0s
# [CV 2/5] END ....C=0.1, gamma=0.001, kernel=rbf;, score=0.667 total time=   0.0s
# [CV 3/5] END ....C=0.1, gamma=0.001, kernel=rbf;, score=0.667 total time=   0.0s
# [CV 4/5] END ....C=0.1, gamma=0.001, kernel=rbf;, score=0.667 total time=   0.0s
# [CV 5/5] END ....C=0.1, gamma=0.001, kernel=rbf;, score=0.650 total time=   0.0s
# [CV 1/5] END ...C=0.1, gamma=0.0001, kernel=rbf;, score=0.667 total time=   0.0s
# [CV 2/5] END ...C=0.1, gamma=0.0001, kernel=rbf;, score=0.667 total time=   0.0s
# [CV 3/5] END ...C=0.1, gamma=0.0001, kernel=rbf;, score=0.667 total time=   0.0s
# [CV 4/5] END ...C=0.1, gamma=0.0001, kernel=rbf;, score=0.667 total time=   0.0s
# [CV 5/5] END ...C=0.1, gamma=0.0001, kernel=rbf;, score=0.650 total time=   0.0s
# [CV 1/5] END ..........C=1, gamma=1, kernel=rbf;, score=0.867 total time=   0.0s
# [CV 2/5] END ..........C=1, gamma=1, kernel=rbf;, score=0.950 total time=   0.0s
# [CV 3/5] END ..........C=1, gamma=1, kernel=rbf;, score=0.883 total time=   0.0s
# [CV 4/5] END ..........C=1, gamma=1, kernel=rbf;, score=0.967 total time=   0.0s
# [CV 5/5] END ..........C=1, gamma=1, kernel=rbf;, score=0.900 total time=   0.0s
# [CV 1/5] END ........C=1, gamma=0.1, kernel=rbf;, score=0.850 total time=   0.0s
# [CV 2/5] END ........C=1, gamma=0.1, kernel=rbf;, score=0.900 total time=   0.0s
# [CV 3/5] END ........C=1, gamma=0.1, kernel=rbf;, score=0.867 total time=   0.0s
# [CV 4/5] END ........C=1, gamma=0.1, kernel=rbf;, score=0.967 total time=   0.0s
# [CV 5/5] END ........C=1, gamma=0.1, kernel=rbf;, score=0.917 total time=   0.0s
# [CV 1/5] END .......C=1, gamma=0.01, kernel=rbf;, score=0.817 total time=   0.0s
# [CV 2/5] END .......C=1, gamma=0.01, kernel=rbf;, score=0.800 total time=   0.0s
# [CV 3/5] END .......C=1, gamma=0.01, kernel=rbf;, score=0.783 total time=   0.0s
# [CV 4/5] END .......C=1, gamma=0.01, kernel=rbf;, score=0.867 total time=   0.0s
# [CV 5/5] END .......C=1, gamma=0.01, kernel=rbf;, score=0.867 total time=   0.0s
# [CV 1/5] END ......C=1, gamma=0.001, kernel=rbf;, score=0.667 total time=   0.0s
# [CV 2/5] END ......C=1, gamma=0.001, kernel=rbf;, score=0.667 total time=   0.0s
# [CV 3/5] END ......C=1, gamma=0.001, kernel=rbf;, score=0.667 total time=   0.0s
# [CV 4/5] END ......C=1, gamma=0.001, kernel=rbf;, score=0.667 total time=   0.0s
# [CV 5/5] END ......C=1, gamma=0.001, kernel=rbf;, score=0.650 total time=   0.0s
# [CV 1/5] END .....C=1, gamma=0.0001, kernel=rbf;, score=0.667 total time=   0.0s
# [CV 2/5] END .....C=1, gamma=0.0001, kernel=rbf;, score=0.667 total time=   0.0s
# [CV 3/5] END .....C=1, gamma=0.0001, kernel=rbf;, score=0.667 total time=   0.0s
# [CV 4/5] END .....C=1, gamma=0.0001, kernel=rbf;, score=0.667 total time=   0.0s
# [CV 5/5] END .....C=1, gamma=0.0001, kernel=rbf;, score=0.650 total time=   0.0s
# [CV 1/5] END .........C=10, gamma=1, kernel=rbf;, score=0.867 total time=   0.0s
# [CV 2/5] END .........C=10, gamma=1, kernel=rbf;, score=0.950 total time=   0.0s
# [CV 3/5] END .........C=10, gamma=1, kernel=rbf;, score=0.883 total time=   0.0s
# [CV 4/5] END .........C=10, gamma=1, kernel=rbf;, score=0.950 total time=   0.0s
# [CV 5/5] END .........C=10, gamma=1, kernel=rbf;, score=0.917 total time=   0.0s
# [CV 1/5] END .......C=10, gamma=0.1, kernel=rbf;, score=0.850 total time=   0.0s
# [CV 2/5] END .......C=10, gamma=0.1, kernel=rbf;, score=0.900 total time=   0.0s
# [CV 3/5] END .......C=10, gamma=0.1, kernel=rbf;, score=0.950 total time=   0.0s
# [CV 4/5] END .......C=10, gamma=0.1, kernel=rbf;, score=0.967 total time=   0.0s
# [CV 5/5] END .......C=10, gamma=0.1, kernel=rbf;, score=0.900 total time=   0.0s
# [CV 1/5] END ......C=10, gamma=0.01, kernel=rbf;, score=0.783 total time=   0.0s
# [CV 2/5] END ......C=10, gamma=0.01, kernel=rbf;, score=0.883 total time=   0.0s
# [CV 3/5] END ......C=10, gamma=0.01, kernel=rbf;, score=0.800 total time=   0.0s
# [CV 4/5] END ......C=10, gamma=0.01, kernel=rbf;, score=0.883 total time=   0.0s
# [CV 5/5] END ......C=10, gamma=0.01, kernel=rbf;, score=0.883 total time=   0.0s
# [CV 1/5] END .....C=10, gamma=0.001, kernel=rbf;, score=0.817 total time=   0.0s
# [CV 2/5] END .....C=10, gamma=0.001, kernel=rbf;, score=0.800 total time=   0.0s
# [CV 3/5] END .....C=10, gamma=0.001, kernel=rbf;, score=0.750 total time=   0.0s
# [CV 4/5] END .....C=10, gamma=0.001, kernel=rbf;, score=0.867 total time=   0.0s
# [CV 5/5] END .....C=10, gamma=0.001, kernel=rbf;, score=0.867 total time=   0.0s
# [CV 1/5] END ....C=10, gamma=0.0001, kernel=rbf;, score=0.667 total time=   0.0s
# [CV 2/5] END ....C=10, gamma=0.0001, kernel=rbf;, score=0.667 total time=   0.0s
# [CV 3/5] END ....C=10, gamma=0.0001, kernel=rbf;, score=0.667 total time=   0.0s
# [CV 4/5] END ....C=10, gamma=0.0001, kernel=rbf;, score=0.667 total time=   0.0s
# [CV 5/5] END ....C=10, gamma=0.0001, kernel=rbf;, score=0.650 total time=   0.0s
# [CV 1/5] END ........C=100, gamma=1, kernel=rbf;, score=0.883 total time=   0.0s
# [CV 2/5] END ........C=100, gamma=1, kernel=rbf;, score=0.883 total time=   0.0s
# [CV 3/5] END ........C=100, gamma=1, kernel=rbf;, score=0.867 total time=   0.0s
# [CV 4/5] END ........C=100, gamma=1, kernel=rbf;, score=0.933 total time=   0.0s
# [CV 5/5] END ........C=100, gamma=1, kernel=rbf;, score=0.917 total time=   0.0s
# [CV 1/5] END ......C=100, gamma=0.1, kernel=rbf;, score=0.850 total time=   0.0s
# [CV 2/5] END ......C=100, gamma=0.1, kernel=rbf;, score=0.900 total time=   0.0s
# [CV 3/5] END ......C=100, gamma=0.1, kernel=rbf;, score=0.933 total time=   0.0s
# [CV 4/5] END ......C=100, gamma=0.1, kernel=rbf;, score=0.967 total time=   0.0s
# [CV 5/5] END ......C=100, gamma=0.1, kernel=rbf;, score=0.933 total time=   0.0s
# [CV 1/5] END .....C=100, gamma=0.01, kernel=rbf;, score=0.850 total time=   0.0s
# [CV 2/5] END .....C=100, gamma=0.01, kernel=rbf;, score=0.933 total time=   0.0s
# [CV 3/5] END .....C=100, gamma=0.01, kernel=rbf;, score=0.933 total time=   0.0s
# [CV 4/5] END .....C=100, gamma=0.01, kernel=rbf;, score=0.967 total time=   0.0s
# [CV 5/5] END .....C=100, gamma=0.01, kernel=rbf;, score=0.900 total time=   0.0s
# [CV 1/5] END ....C=100, gamma=0.001, kernel=rbf;, score=0.817 total time=   0.0s
# [CV 2/5] END ....C=100, gamma=0.001, kernel=rbf;, score=0.850 total time=   0.0s
# [CV 3/5] END ....C=100, gamma=0.001, kernel=rbf;, score=0.800 total time=   0.0s
# [CV 4/5] END ....C=100, gamma=0.001, kernel=rbf;, score=0.867 total time=   0.0s
# [CV 5/5] END ....C=100, gamma=0.001, kernel=rbf;, score=0.867 total time=   0.0s
# [CV 1/5] END ...C=100, gamma=0.0001, kernel=rbf;, score=0.817 total time=   0.0s
# [CV 2/5] END ...C=100, gamma=0.0001, kernel=rbf;, score=0.783 total time=   0.0s
# [CV 3/5] END ...C=100, gamma=0.0001, kernel=rbf;, score=0.750 total time=   0.0s
# [CV 4/5] END ...C=100, gamma=0.0001, kernel=rbf;, score=0.867 total time=   0.0s
# [CV 5/5] END ...C=100, gamma=0.0001, kernel=rbf;, score=0.867 total time=   0.0s
# [CV 1/5] END .......C=1000, gamma=1, kernel=rbf;, score=0.867 total time=   0.0s
# [CV 2/5] END .......C=1000, gamma=1, kernel=rbf;, score=0.900 total time=   0.0s
# [CV 3/5] END .......C=1000, gamma=1, kernel=rbf;, score=0.867 total time=   0.0s
# [CV 4/5] END .......C=1000, gamma=1, kernel=rbf;, score=0.900 total time=   0.0s
# [CV 5/5] END .......C=1000, gamma=1, kernel=rbf;, score=0.883 total time=   0.0s
# [CV 1/5] END .....C=1000, gamma=0.1, kernel=rbf;, score=0.833 total time=   0.0s
# [CV 2/5] END .....C=1000, gamma=0.1, kernel=rbf;, score=0.917 total time=   0.0s
# [CV 3/5] END .....C=1000, gamma=0.1, kernel=rbf;, score=0.917 total time=   0.0s
# [CV 4/5] END .....C=1000, gamma=0.1, kernel=rbf;, score=0.967 total time=   0.0s
# [CV 5/5] END .....C=1000, gamma=0.1, kernel=rbf;, score=0.917 total time=   0.0s
# [CV 1/5] END ....C=1000, gamma=0.01, kernel=rbf;, score=0.867 total time=   0.0s
# [CV 2/5] END ....C=1000, gamma=0.01, kernel=rbf;, score=0.917 total time=   0.0s
# [CV 3/5] END ....C=1000, gamma=0.01, kernel=rbf;, score=0.950 total time=   0.0s
# [CV 4/5] END ....C=1000, gamma=0.01, kernel=rbf;, score=0.967 total time=   0.0s
# [CV 5/5] END ....C=1000, gamma=0.01, kernel=rbf;, score=0.900 total time=   0.0s
# [CV 1/5] END ...C=1000, gamma=0.001, kernel=rbf;, score=0.783 total time=   0.0s
# [CV 2/5] END ...C=1000, gamma=0.001, kernel=rbf;, score=0.867 total time=   0.0s
# [CV 3/5] END ...C=1000, gamma=0.001, kernel=rbf;, score=0.817 total time=   0.0s
# [CV 4/5] END ...C=1000, gamma=0.001, kernel=rbf;, score=0.900 total time=   0.0s
# [CV 5/5] END ...C=1000, gamma=0.001, kernel=rbf;, score=0.883 total time=   0.0s
# [CV 1/5] END ..C=1000, gamma=0.0001, kernel=rbf;, score=0.817 total time=   0.0s
# [CV 2/5] END ..C=1000, gamma=0.0001, kernel=rbf;, score=0.850 total time=   0.0s
# [CV 3/5] END ..C=1000, gamma=0.0001, kernel=rbf;, score=0.800 total time=   0.0s
# [CV 4/5] END ..C=1000, gamma=0.0001, kernel=rbf;, score=0.867 total time=   0.0s
# [CV 5/5] END ..C=1000, gamma=0.0001, kernel=rbf;, score=0.850 total time=   0.0s
# GridSearchCV(estimator=SVC(max_iter=1000000000),
#              param_grid={'C': [0.1, 1, 10, 100, 1000],
#                          'gamma': [1, 0.1, 0.01, 0.001, 0.0001],
#                          'kernel': ['rbf']},
#              verbose=3)

# %%
print('The best parameters (on the training data) are %s with a score of %0.2f.' 
      % (grid.best_params_, grid.best_score_))
# Out:
# The best parameters (on the training data) are {'C': 1000, 'gamma': 0.01, 'kernel': 'rbf'} with a score of 0.92.

# %%
grid.best_params_
# Out:
# {'C': 1000, 'gamma': 0.01, 'kernel': 'rbf'}

# %%
#Now we have everything in grid, including the best one, so we can just use that:
grid_predictions = grid.predict(X_train)

# %%
print(confusion_matrix(y_train,grid_predictions))
print(classification_report(y_train,grid_predictions))
# Out:
# [[188  11]
#  [ 14  87]]
#               precision    recall  f1-score   support
#
#            0       0.93      0.94      0.94       199
#            1       0.89      0.86      0.87       101
#
#     accuracy                           0.92       300
#    macro avg       0.91      0.90      0.91       300
# weighted avg       0.92      0.92      0.92       300

# %%
print("Compare the training score of %0.2f, with a score of %0.2f \nwhen the test data is passed through the model." 
      % (grid.best_score_, grid.score(X_test, y_test)))
# Out:
# Compare the training score of 0.92, with a score of 0.88
# when the test data is passed through the model.

# %% [markdown]
# ## Naive Bayes Classifier

# %% [markdown]
# From ScikitLearn - "These classifiers are based on applying Bayes’ theorem with the “naive” assumption of conditional independence between every pair of features given the value of the class variable.
# i.e. It assumes the presence of a particular feature in a class is unrelated to the presence of any other feature.
#
# In spite of their apparently over-simplified assumptions, naive Bayes classifiers have worked quite well in many real-world situations, famously document classification and spam filtering. They require a small amount of training data to estimate the necessary parameters."
#
# They do well at guessing the label (a good classifier), but it is known to be a bad estimator - so don't rely on the specific probability.
#
# Good model choice for text classification and sentiment analysis where there is high dimensionality (lots of words!) and independence between words is a good assumption actually.

# %%
from sklearn.naive_bayes import GaussianNB
model_NB = GaussianNB().fit(X_train, y_train)

y_pred_NB = model_NB.predict(X_test)
print(confusion_matrix(y_test,y_pred_NB))
print(classification_report(y_test,y_pred_NB))
# Out:
# [[51  7]
#  [ 7 35]]
#               precision    recall  f1-score   support
#
#            0       0.88      0.88      0.88        58
#            1       0.83      0.83      0.83        42
#
#     accuracy                           0.86       100
#    macro avg       0.86      0.86      0.86       100
# weighted avg       0.86      0.86      0.86       100
