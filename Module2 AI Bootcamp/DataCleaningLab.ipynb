# %% [markdown]
# Mission instructions:
#
# The Cereals dataset has a plethora of categorical attributes, you will now use it for practicing!
#
# To complete this mission, perform the following task in the editor provided:
#
# Step 1: multiply the “weight” attribute of the dataset by 20.
#
# Step 2: replace the capital letter of “type” attribute with a smaller one.
#
# Step 3: return the dataset after modification.

# %%
import pandas as pd
dataset = pd.read_csv('cereal.csv')

dataset.head(6)
#Step 1 Multiply the Weight  attribute of the dataset by 20
dataset['weight'] = dataset['weight'] * 20
print(dataset.head(6)) 
#step 2 Replace the Capital Letter of "type" with a smaller one
dataset['type'] = dataset['type'].str.lower()
print(dataset.head(6))
#step3 Return the dataset after modification
print(dataset)
# Out:
#                         name mfr type  calories  protein  fat  sodium  fiber  \
# 0                  100% Bran   N    C        70        4    1     130   10.0
# 1          100% Natural Bran   Q    C       120        3    5      15    2.0
# 2                   All-Bran   K    C        70        4    1     260    9.0
# 3  All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# 4             Almond Delight   R    C       110        2    2     200    1.0
# 5    Apple Cinnamon Cheerios   G    C       110        2    2     180    1.5
#
#    carbo  sugars  potass  vitamins  shelf  weight  cups     rating
# 0    5.0       6     280        25      3    20.0  0.33  68.402973
# 1    8.0       8     135         0      3    20.0  1.00  33.983679
# 2    7.0       5     320        25      3    20.0  0.33  59.425505
# 3    8.0       0     330        25      3    20.0  0.50  93.704912
# 4   14.0       8      -1        25      3    20.0  0.75  34.384843
# ...
