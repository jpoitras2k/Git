# %% [markdown]
# Breast Cancer Campaign - Mini Project
# After the delivery of the first part of the Campaign successfully, the company wanted to implement a simple classification model that would classify the diagnosis for a patient based on the same features collected from the Wisconsin Breast Cancer dataset.
# You are required to:
# Select the most important features in the Breast Cancer dataset.
# Train multiple classifiers on the dataset to predict the diagnosis class.
# Achieve an acceptable accuracy score.
